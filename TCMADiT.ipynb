# %%
import pandas as pd

# 读取txt文件，假设逗号分隔
df = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\solid\\bacteria.WXS.solid.file.reads.txt', delimiter='\t')
df.to_csv('D:\\TCGA\\mbVDiT_data\\WXS\\solid\\bacteria.WXS.solid.file.reads.csv', index=False)
print("TXT文件已成功保存为CSV文件。")

# 读取txt文件，假设逗号分隔
df = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\solid\\metadata.WXS.solid.file.txt', delimiter='\t')
df.to_csv('D:\\TCGA\\mbVDiT_data\\WXS\\solid\\metadata.WXS.solid.file.csv', index=False)
print("TXT文件已成功保存为CSV文件。")

# 读取CSV文件，并将空字符串识别为缺失值（NaN）
df = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\solid\\bacteria.WXS.solid.file.reads.csv', na_values=[''])
# 删除包含缺失值的行
df_cleaned = df.dropna()
# 保存清理后的数据到一个新的CSV文件
df_cleaned.to_csv('D:\\TCGA\\mbVDiT_data\\WXS\\solid\\csvcleaned_file.csv', index=False)
print("包含空值的行已删除，并保存到新的CSV文件。")

wxs_solid = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\solid\\csvcleaned_file.csv')
wxs_solid
# Out:
# TXT文件已成功保存为CSV文件。
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10220\2686689840.py:9: DtypeWarning: Columns (3,18,36,54,79,100,128,131,137,141,152,176,182,189,191,193,205,215,216,217,218,219,221,223,227,228,229,231,232,233,247,248,249,285,286,287,288,289,290,291,292,295,297,298,299,300,302,305,306,307,308,309,310,311,312,313,314,315,316,317,318,320,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,339,340,341,342,343,344,345,346,347,349,350,351) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\solid\\metadata.WXS.solid.file.txt', delimiter='\t')
# TXT文件已成功保存为CSV文件。
# 包含空值的行已删除，并保存到新的CSV文件。
#      Unnamed: 0  00b7ee04-b97b-49ee-b27b-13f6fb981fec  \
# 0           2.0                          17350.620633
# 1         194.0                              0.000000
# 2         203.0                              0.000000
# 3         204.0                              0.000000
# ...

# %%
import pandas as pd

# 读取txt文件，假设逗号分隔
df = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\blood\\bacteria.WXS.blood.file.reads.txt', delimiter='\t')
# 保存为csv文件
df.to_csv('D:\\TCGA\\mbVDiT_data\\WXS\\blood\\bacteria.WXS.blood.file.reads.csv', index=False)
print("TXT文件已成功保存为CSV文件。")

# 读取txt文件，假设逗号分隔
df = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\blood\\metadata.WXS.blood.file.txt', delimiter='\t')
# 保存为csv文件
df.to_csv('D:\\TCGA\\mbVDiT_data\\WXS\\blood\\metadata.WXS.blood.file.csv', index=False)
print("TXT文件已成功保存为CSV文件。")

# 读取CSV文件，并将空字符串识别为缺失值（NaN）
df = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\blood\\bacteria.WXS.blood.file.reads.csv', na_values=[''])
# 删除包含缺失值的行
df_cleaned = df.dropna()
# 保存清理后的数据到一个新的CSV文件
df_cleaned.to_csv('D:\\TCGA\\mbVDiT_data\\WXS\\blood\\csvcleaned_file.csv', index=False)
print("包含空值的行已删除，并保存到新的CSV文件。")

wxs_blood = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\blood\\csvcleaned_file.csv')
wxs_blood
# Out:
# TXT文件已成功保存为CSV文件。
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10220\132767167.py:10: DtypeWarning: Columns (3,18,36,54,79,100,128,131,137,141,152,176,182,189,191,193,205,215,216,217,218,219,221,223,227,228,229,231,232,233,247,248,249,285,286,287,288,289,290,291,292,295,297,298,299,300,302,305,306,307,308,309,310,311,312,313,314,315,316,317,318,320,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,339,340,341,342,343,344,345,346,347,349,350,351) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\blood\\metadata.WXS.blood.file.txt', delimiter='\t')
# TXT文件已成功保存为CSV文件。
# 包含空值的行已删除，并保存到新的CSV文件。
#      Unnamed: 0  00ec5e0d-ffb4-4975-9bec-75d88a5a5411  \
# 0           2.0                             70.764706
# 1         194.0                              0.000000
# 2         203.0                              0.000000
# 3         204.0                              0.000000
# ...

# %%
wxs_solid_samples = wxs_solid.columns

# %%
wxs_blood_samples = wxs_blood.columns

# %%
wxs_solid_meta = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\solid\\metadata.WXS.solid.file.csv')
wxs_solid_file_id = wxs_solid_meta['file_id']    
wxs_solid_barcode = wxs_solid_meta['case.bcr_patient_barcode']
wxs_solid_sample_id = []
index = 0
for i in range (len(wxs_solid_samples)):
    k = 0
    for j in range (len(wxs_solid_file_id)):
        if wxs_solid_samples[i] == wxs_solid_file_id[j]:
            index = j
            k = 1
    if k == 1:
        wxs_solid_sample_id.append(wxs_solid_barcode[index])
len(wxs_solid_sample_id)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10220\597736544.py:1: DtypeWarning: Columns (3,18,36,54,79,100,128,131,137,141,152,176,182,189,191,193,205,215,216,217,218,219,221,223,227,228,229,231,232,233,247,248,249,285,286,287,288,289,290,291,292,295,297,298,299,300,302,305,306,307,308,309,310,311,312,313,314,315,316,317,318,320,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,339,340,341,342,343,344,345,346,347,349,350,351) have mixed types. Specify dtype option on import or set low_memory=False.
#   wxs_solid_meta = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\solid\\metadata.WXS.solid.file.csv')
# 2108

# %%
wxs_blood_meta = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\blood\\metadata.WXS.blood.file.csv')
wxs_blood_file_id = wxs_blood_meta['file_id']    
wxs_blood_barcode = wxs_blood_meta['case.bcr_patient_barcode']
wxs_blood_sample_id = []
index = 0
for i in range (len(wxs_blood_samples)):
    k = 0
    for j in range (len(wxs_blood_file_id)):
        if wxs_blood_samples[i] == wxs_blood_file_id[j]:
            index = j
            k = 1
    if k == 1:
        wxs_blood_sample_id.append(wxs_blood_barcode[index])
len(wxs_blood_sample_id)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10220\781542275.py:1: DtypeWarning: Columns (3,18,36,54,79,100,128,131,137,141,152,176,182,189,191,193,205,215,216,217,218,219,221,223,227,228,229,231,232,233,247,248,249,285,286,287,288,289,290,291,292,295,297,298,299,300,302,305,306,307,308,309,310,311,312,313,314,315,316,317,318,320,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,339,340,341,342,343,344,345,346,347,349,350,351) have mixed types. Specify dtype option on import or set low_memory=False.
#   wxs_blood_meta = pd.read_csv('D:\\TCGA\\mbVDiT_data\\WXS\\blood\\metadata.WXS.blood.file.csv')
# 1594

# %%
wxs_solid_sample_id
# Out:
# ['TCGA-CK-4952',
#  'TCGA-AZ-6601',
#  'TCGA-A6-5656',
#  'TCGA-AZ-4315',
#  'TCGA-T9-A92H',
#  'TCGA-A6-5661',
#  'TCGA-AZ-4684',
#  'TCGA-AA-3811',
#  'TCGA-AA-3980',
#  'TCGA-F4-6569',
#  'TCGA-AA-3516',
#  'TCGA-AA-3558',
#  'TCGA-AA-3966',
#  'TCGA-CM-6168',
#  'TCGA-CM-4748',
#  'TCGA-F4-6854',
#  'TCGA-AA-3667',
#  'TCGA-G4-6320',
#  'TCGA-F4-6855',
#  'TCGA-D5-6540',
#  'TCGA-5M-AATE',
#  'TCGA-AZ-6600',
#  'TCGA-G4-6323',
#  'TCGA-QG-A5Z1',
#  'TCGA-AA-3673',
#  'TCGA-A6-2681',
#  'TCGA-AZ-4681',
#  'TCGA-NH-A6GC',
#  'TCGA-AA-3976',
#  'TCGA-AA-A01I',
#  'TCGA-AZ-4615',
#  'TCGA-F4-6459',
#  'TCGA-A6-3810',
#  'TCGA-AA-3517',
#  'TCGA-AY-6386',
#  'TCGA-G4-6310',
#  'TCGA-AA-3842',
#  'TCGA-AA-3534',
#  'TCGA-CM-4752',
#  'TCGA-AA-3815',
#  'TCGA-NH-A8F7',
#  'TCGA-AA-3710',
#  'TCGA-AA-A01D',
#  'TCGA-AA-3529',
#  'TCGA-AA-A017',
#  'TCGA-AA-3548',
#  'TCGA-AA-3982',
#  'TCGA-AZ-6606',
#  'TCGA-AA-3984',
#  'TCGA-AA-3509',
#  'TCGA-AM-5820',
#  'TCGA-G4-6307',
# ...

# %%
wxs_blood_sample_id
# Out:
# ['TCGA-A6-2680',
#  'TCGA-D5-6926',
#  'TCGA-CK-6748',
#  'TCGA-G4-6295',
#  'TCGA-AA-A02H',
#  'TCGA-AA-3527',
#  'TCGA-DM-A282',
#  'TCGA-D5-6530',
#  'TCGA-CM-5864',
#  'TCGA-AA-A01K',
#  'TCGA-CM-5861',
#  'TCGA-AZ-4615',
#  'TCGA-AU-3779',
#  'TCGA-SS-A7HO',
#  'TCGA-CM-4748',
#  'TCGA-AA-3530',
#  'TCGA-AA-3819',
#  'TCGA-D5-6533',
#  'TCGA-QG-A5YX',
#  'TCGA-AZ-5403',
#  'TCGA-AA-A02R',
#  'TCGA-AA-A02Y',
#  'TCGA-AA-3979',
#  'TCGA-AA-3980',
#  'TCGA-DM-A28G',
#  'TCGA-CK-4950',
#  'TCGA-CM-6674',
#  'TCGA-AA-3947',
#  'TCGA-AA-3695',
#  'TCGA-QL-A97D',
#  'TCGA-AA-3984',
#  'TCGA-CA-6719',
#  'TCGA-AA-3821',
#  'TCGA-AA-3949',
#  'TCGA-A6-6650',
#  'TCGA-AA-3862',
#  'TCGA-AA-3526',
#  'TCGA-DM-A1HB',
#  'TCGA-CK-4948',
#  'TCGA-AU-6004',
#  'TCGA-AY-A71X',
#  'TCGA-AY-6197',
#  'TCGA-AA-3994',
#  'TCGA-A6-2675',
#  'TCGA-A6-2677',
#  'TCGA-CM-5348',
#  'TCGA-G4-6303',
#  'TCGA-G4-6323',
#  'TCGA-D5-6932',
#  'TCGA-D5-5538',
#  'TCGA-A6-A56B',
#  'TCGA-AA-3679',
# ...

# %%
consisit_sample = []
t = 0
for i in range (len(wxs_solid_sample_id)):
    for j in range(len(wxs_blood_sample_id)):
        if wxs_solid_sample_id[i] == wxs_blood_sample_id[j]:
            print(i, j, wxs_solid_sample_id[i], wxs_blood_sample_id[j])
            t = t + 1
            continue
# Out:
# 0 60 TCGA-CK-4952 TCGA-CK-4952
# 2 69 TCGA-A6-5656 TCGA-A6-5656
# 2 229 TCGA-A6-5656 TCGA-A6-5656
# 3 330 TCGA-AZ-4315 TCGA-AZ-4315
# 4 65 TCGA-T9-A92H TCGA-T9-A92H
# 5 66 TCGA-A6-5661 TCGA-A6-5661
# 6 114 TCGA-AZ-4684 TCGA-AZ-4684
# 7 88 TCGA-AA-3811 TCGA-AA-3811
# 8 23 TCGA-AA-3980 TCGA-AA-3980
# 9 312 TCGA-F4-6569 TCGA-F4-6569
# 11 336 TCGA-AA-3558 TCGA-AA-3558
# 12 268 TCGA-AA-3966 TCGA-AA-3966
# 13 289 TCGA-CM-6168 TCGA-CM-6168
# 14 14 TCGA-CM-4748 TCGA-CM-4748
# 15 353 TCGA-F4-6854 TCGA-F4-6854
# 16 172 TCGA-AA-3667 TCGA-AA-3667
# 17 86 TCGA-G4-6320 TCGA-G4-6320
# 18 218 TCGA-F4-6855 TCGA-F4-6855
# 19 296 TCGA-D5-6540 TCGA-D5-6540
# 20 240 TCGA-5M-AATE TCGA-5M-AATE
# 22 47 TCGA-G4-6323 TCGA-G4-6323
# 23 251 TCGA-QG-A5Z1 TCGA-QG-A5Z1
# 24 235 TCGA-AA-3673 TCGA-AA-3673
# 25 369 TCGA-A6-2681 TCGA-A6-2681
# 26 68 TCGA-AZ-4681 TCGA-AZ-4681
# 27 155 TCGA-NH-A6GC TCGA-NH-A6GC
# 28 170 TCGA-AA-3976 TCGA-AA-3976
# 29 193 TCGA-AA-A01I TCGA-AA-A01I
# 30 11 TCGA-AZ-4615 TCGA-AZ-4615
# ...

# %%
t
# Out:
# 1772

# %%
microdata = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\metadata.WXS.solid.file.csv')
microdata
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10220\1139135178.py:1: DtypeWarning: Columns (3,18,36,54,79,100,128,131,137,141,152,176,182,189,191,193,205,215,216,217,218,219,221,223,227,228,229,231,232,233,247,248,249,285,286,287,288,289,290,291,292,295,297,298,299,300,302,305,306,307,308,309,310,311,312,313,314,315,316,317,318,320,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,339,340,341,342,343,344,345,346,347,349,350,351) have mixed types. Specify dtype option on import or set low_memory=False.
#   microdata = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\metadata.WXS.solid.file.csv')
#                                    file_id adapter_content  \
# 0     22eeeeaf-8aa8-45e6-ace6-b84917c3b402             NaN
# 1     a191bf4a-e494-4741-963f-04125c2a7d25             NaN
# 2     a27b491f-dfce-4f7b-a18c-8ada5309959c             NaN
# 3     4ca4d097-aba8-4b2e-80ef-1c1b06463366             NaN
# 4     b96e4a5b-ccba-4670-96a2-87b4bde329ea             NaN
# ...

# %%
microdata.loc[5615:, : ]
# Out:
#                                    file_id adapter_content  \
# 5615  99084bc3-84ee-4ccc-9c54-1b5a74af410b             NaN
# 5616  a1feb789-c851-4608-a5c1-382bb432c4c7             NaN
# 5617  9830e4a0-d8b1-4166-8375-49851288cf1f             NaN
# 5618  05762233-5294-478d-b462-14b931579f63             NaN
# 5619  144edb0d-1d38-420e-a1b5-ea974935bacf             NaN
# ...                                    ...             ...
# 7776  0267b745-8d59-4b5e-af31-92e48b8a8d4d            PASS
# 7777  e8f839fc-487d-4135-9313-649dc2f66206            PASS
# 7778  cd10686d-b985-4fdc-8073-63dcc9e7a6b1            PASS
# 7779  e0ed36a9-4d17-4b3d-bec8-5765c9a53a64            PASS
# 7780  31fe7131-31b4-46e5-a65c-7719193dd73e            PASS
#
#                                 aliquot_id  \
# 5615  e58458dc-b614-466b-863d-428b18fd3a64
# 5616  b27fac46-97c3-4262-b8cb-6e15aa75483a
# 5617  c612570a-881d-421f-98b9-0e4563133744
# 5618  f262dded-846f-4deb-8fc3-ef0df814eca4
# ...

# %%
data = microdata.loc[5615:, : ]
data.to_csv('D:\\TCGA\\mbVDiT_data\\WXS\\solid\\stad\\metadata.csv', index=False)

# %%
sample = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\csvcleaned_file.csv', index_col=0).columns
micsample=sample.tolist()
micsample
# Out:
# ['00b7ee04-b97b-49ee-b27b-13f6fb981fec',
#  '00f789a0-bc97-48a3-abff-51d0acaff845',
#  '012fc920-2c94-4596-a937-9e6f6a3fffd8',
#  '014560ce-4236-4fbe-8f1c-ac5c67bc1517',
#  '026ac354-163a-44c3-8b8e-25365c0998be',
#  '02821c27-c53f-495a-8043-fce0359c75ed',
#  '03d31c4a-bf43-4ae5-b4a3-588b16e9ed71',
#  '04a38123-6191-4848-8b0e-3a6b1749e2a7',
#  '050a26dc-7ee4-4c5b-be2a-2a315a5d1182',
#  '059312aa-f536-48f6-92e4-978219e96598',
#  '059b364e-8dd3-40ad-b9ce-f4710041e0a2',
#  '05b9ad95-bde4-4168-bd18-b9f058f7575a',
#  '05d73da9-f655-4b92-840e-fca14bfd1ad7',
#  '079c518c-5452-4d78-8d96-c49d6ae5a05b',
#  '07fe1566-0485-4da5-8d00-00b5cc481264',
#  '08c1d8ff-ce77-4add-8c80-6e52f53f4911',
#  '08fa625f-4793-4d85-9032-e8f25161ed93',
#  '09d399af-60fb-4aa7-899b-75578a291984',
#  '09e6c467-e719-40de-8840-4dd11e4dc0f7',
#  '0b0f9b88-124f-451d-aa5d-a3b8c80f5a50',
#  '0bb88200-c1e2-4417-ba37-b5d0248dd5ce',
#  '0ce1cfa1-b577-4d05-972e-bad94c318243',
#  '0cf81f39-07cb-4687-a709-51d6e9009ca1',
# ...

# %%
meta = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\stad\\metadata.csv')
metasample=meta['file_id'].tolist()
metasample
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10220\1028369053.py:1: DtypeWarning: Columns (3,16,35,39,40,54,79,80,81,121,161,180) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\stad\\metadata.csv')
# ['99084bc3-84ee-4ccc-9c54-1b5a74af410b',
#  'a1feb789-c851-4608-a5c1-382bb432c4c7',
#  '9830e4a0-d8b1-4166-8375-49851288cf1f',
#  '05762233-5294-478d-b462-14b931579f63',
#  '144edb0d-1d38-420e-a1b5-ea974935bacf',
#  '4a0c62bb-6857-41e2-8933-37b5cb32f6b7',
#  'ae26ff46-1bed-4f41-92ca-b21924966143',
#  'c4e25e33-1ac2-427d-adeb-7d6cfc0269a6',
#  '9470ad93-71f4-4d5d-a26b-8cec32d802dc',
#  '87a698be-8fb0-4ced-842b-fdc852b98aa8',
#  'e69add2b-1a4d-44e6-8186-3fb2163afa5f',
#  '002ff9b2-954c-4a9c-9f81-b5919872e770',
#  'f7df3714-78fc-460f-8d69-6870f63c1f49',
#  '67df24ad-ea00-45a4-b4b5-b494b97f34df',
#  '97a524b1-432a-4c20-adcf-5e45ee168834',
#  'e9116b76-5b39-48ec-802b-70e4c7eec731',
# ...

# %%
len(micsample), len(metasample)
# Out:
# (2108, 691)

# %%
index = []
sampleid = []
for i in range(len(micsample)):
    for j in range(len(metasample)):
        if micsample[i] == metasample[j]:
            index.append(i)
            sampleid.append(micsample[i])
            print(i,j)
# Out:
# 1330 199
# 1331 226
# 1332 503
# 1333 351
# 1334 194
# 1335 396
# 1336 464
# 1337 233
# 1338 190
# 1339 349
# 1340 357
# 1341 154
# 1342 280
# 1343 344
# 1344 494
# 1345 270
# 1346 322
# 1347 222
# 1348 408
# 1349 400
# 1350 358
# 1351 174
# 1352 451
# 1353 410
# 1354 282
# 1355 315
# 1356 359
# 1357 437
# 1358 447
# 1359 340
# 1360 455
# 1361 369
# 1362 505
# 1363 495
# 1364 422
# 1365 342
# 1366 219
# 1367 218
# 1368 509
# 1369 453
# 1370 175
# 1371 284
# 1372 474
# 1373 450
# 1374 230
# 1375 272
# 1376 281
# 1377 401
# 1378 425
# 1379 310
# 1380 432
# 1381 206
# 1382 159
# 1383 374
# 1384 276
# 1385 201
# 1386 421
# 1387 164
# 1388 491
# 1389 403
# 1390 184
# 1391 465
# 1392 167
# 1393 423
# 1394 380
# 1395 488
# 1396 244
# 1397 473
# 1398 350
# 1399 235
# 1400 371
# 1401 208
# 1402 492
# 1403 483
# 1404 502
# 1405 368
# 1406 405
# 1407 463
# 1408 258
# 1409 346
# 1410 181
# 1411 496
# 1412 489
# 1413 171
# 1414 389
# 1415 470
# 1416 456
# 1417 256
# 1418 517
# 1419 185
# ...

# %%
sampleid
# Out:
# ['0038dc24-f02e-4be2-8deb-19c081d7d548',
#  '00a7766f-f90c-45ea-afe2-2d505827c415',
#  '01c1eccc-fb5b-4f89-a88a-5e1cd6b403e0',
#  '028d1914-f43c-44f3-8ff9-9a13c7e99d0f',
#  '02ae7490-c0ce-4749-9bd4-9cb88643cead',
#  '046eaa7e-6212-4a9f-bc59-1cf439f92fe0',
#  '0494ee12-b519-4dcf-b031-5ad3e975aeb7',
#  '05874944-eca6-4bc6-9359-a68b64015ba6',
#  '065620af-1203-4ee7-8361-7fbb2df86518',
#  '0790f9b2-9fe9-4a7f-a64a-4fb52e218652',
#  '07e57a26-eee2-4505-b799-c10c327e4c16',
#  '087f7b07-0952-46b5-9787-616bdecf9476',
#  '08ecce69-3353-44c5-9694-bcd13e5e35f2',
#  '0bd5c33d-08da-41cf-9f13-ccaa664e34cf',
#  '0d605d48-174b-44af-8a9b-1403b70ba16d',
#  '0e889b37-9e68-4359-b3eb-2e37ae623372',
#  '0f080608-cb65-435b-bb5a-1e6fed18db5d',
#  '0f8a2988-ef44-4952-af73-31420028019f',
#  '10496104-358d-4079-9c14-114c2d741ecd',
#  '10a63aba-06a3-4209-8b59-dcb499e632ea',
#  '13794d66-5440-47ae-925e-ad5053c36720',
#  '14955ce7-aa53-4ca4-8e22-fce0e025a92a',
#  '14e48042-7aad-4c05-8a2c-0bd65e1c0138',
# ...

# %%
len(sampleid)
# Out:
# 248

# %%
data = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\csvcleaned_file.csv', index_col=0)
selected_columns = data[sampleid]
selected_columns
# Out:
#             0038dc24-f02e-4be2-8deb-19c081d7d548  \
# Unnamed: 0
# 2.0                                          0.0
# 194.0                                        0.0
# 203.0                                        0.0
# 204.0                                        0.0
# 815.0                                        0.0
# ...                                          ...
# 1739543.0                                    0.0
# 1843489.0                                    0.0
# 1852365.0                                    0.0
# 1853231.0                                    0.0
# 1917878.0                                    0.0
#
#             00a7766f-f90c-45ea-afe2-2d505827c415  \
# Unnamed: 0
# 2.0                                    37.695652
# 194.0                                   0.000000
# 203.0                                   0.000000
# 204.0                                   0.000000
# 815.0                                   0.000000
# ...

# %%
selected_columns.to_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\esca\\csvcleaned_file.csv')

# %%
# Out:
#             0038dc24-f02e-4be2-8deb-19c081d7d548  \
# Unnamed: 0
# 2.0                                          0.0
# 194.0                                        0.0
# 203.0                                        0.0
# 204.0                                        0.0
# 815.0                                        0.0
# ...                                          ...
# 1739543.0                                    0.0
# 1843489.0                                    0.0
# 1852365.0                                    0.0
# 1853231.0                                    0.0
# 1917878.0                                    0.0
#
#             00a7766f-f90c-45ea-afe2-2d505827c415  \
# Unnamed: 0
# 2.0                                    37.695652
# 194.0                                   0.000000
# 203.0                                   0.000000
# 204.0                                   0.000000
# 815.0                                   0.000000
# ...

# %%
test = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\hnsc\\csvcleaned_file.csv', index_col=0, header=0)
import numpy as np
# 计算0的数量
zero_count = np.sum(test.values == 0)

# 计算总数据数量
total_count = test.values.size

# 计算0占的百分比
zero_percentage = (zero_count / total_count) * 100
zero_percentage
# Out:
# 79.63099868213816

# %%
import anndata as ad
adata = ad.AnnData(test.T)
adata.write('D:\\TCGA\mbVDiT_data\\WXS\\solid\\hnsc\\microdata.h5ad')
# Out:
# D:\Anaconda\envs\DL\lib\site-packages\anndata\_core\anndata.py:183: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
idf = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\hnsc\\csvcleaned_file.csv', index_col=0, header=0)
idf.columns
# Out:
# Index(['00296c5e-2e37-4d90-ba8c-ac466a7f71f1',
#        '004baf22-9eea-47db-b414-d84ff8ec728e',
#        '00e1676d-b6c5-4d72-b69c-0110e38f6aef',
#        '01508ee7-c807-4831-a0d9-20181cddd3ff',
#        '017260da-a89f-42c5-9c88-e8d3d09b41c3',
#        '021563e6-29fa-463a-986c-24046ce2dfbf',
#        '026f474b-c104-40fb-a6a6-ebb81672adc3',
#        '02c8ccd0-20a7-41f7-8b94-7937c640c82e',
#        '036154a7-5b86-43dd-888a-15d20016be18',
#        '036bd87e-37de-4718-bafb-b81e0003d788',
#        ...
#        'fbe9a582-059a-4eaa-8cb6-aec6eb666df5',
#        'fbec4056-604e-4014-b952-c38903a036f9',
#        'fc7c1a67-f654-41b4-bb52-10c823607297',
#        'fcccab2f-c0a2-4349-ba3c-a629d4e5ca23',
#        'fd0e07fe-b542-4038-85f7-43aa25b2153c',
#        'fdba865e-5db6-4d14-8260-766a699fbaf1',
#        'ff07d83f-411c-4143-a60c-7b377809cc91',
#        'ff1bcd6d-2917-412b-9f51-c8d7c90aed99',
#        'ffa9d988-2874-4e79-b1f9-6af5dfd61736',
#        'ffdbb099-fda4-4ec8-ae3b-3e0a81296ba7'],
# ...

# %%
meta = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\hnsc\\metadata.csv')
metasample=meta['file_id'].tolist()
metasample
# Out:
# ['74dfb1a3-cdd5-4360-923f-2c18cd7e6044',
#  '17aee7fb-ed6f-46de-8dc7-ad13153b83a3',
#  'b54a3eac-9c58-453d-9db1-395601ae82ea',
#  'f81e667a-9c30-4093-8e59-c8fa7f8b772c',
#  'ab5f1c0e-d07d-49b4-9fc2-b74f3c4928a6',
#  'e5709830-4141-4354-94f0-94f576fe84c9',
#  '33b84364-a81e-48fd-89d6-552802c7ff18',
#  'e7b9cb7d-0a1a-4461-ab89-108d02821762',
#  'dac94d31-7c1f-4e4b-98af-a3a585b86fae',
#  '82ff50a2-3252-4ce5-a0ad-979cce2ec4cb',
#  '70f8bf18-8050-4dad-9029-c90972a9bfb4',
#  '3fb0505f-e847-4658-93f1-0af7d8617e66',
#  'c96f69ef-daa9-46cf-b34f-d7c328956edd',
#  'db7d0f46-b4eb-4cad-8324-08d0a5781624',
#  'bd85b141-d240-412f-9b74-379c4e3797d2',
#  '03c22e39-15a9-4b8a-8db1-cf41d618b7fc',
#  '2dc9d158-11f1-4d04-a6e6-8075121def2e',
#  '44d87ab1-c19b-4411-8774-2f888600c978',
#  '878f4d9b-a3fb-4517-9331-fe3b4590447e',
#  'bb531fb4-064f-47dd-8231-bd6131866968',
#  'e5e36209-eb45-4a7f-b70a-547a36daace6',
#  '3eb627a6-bbcf-4699-ad23-e52a26cd4453',
#  '7145e1a2-e609-45d9-a111-efe59656286d',
# ...

# %%
metatype = meta['sample.sample_type'].tolist()
metatype
# Out:
# ['Blood Derived Normal',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Solid Tissue Normal',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Blood Derived Normal',
#  'Blood Derived Normal',
#  'Blood Derived Normal',
#  'Primary Tumor',
#  'Blood Derived Normal',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Blood Derived Normal',
#  'Blood Derived Normal',
#  'Solid Tissue Normal',
#  'Primary Tumor',
#  'Blood Derived Normal',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Blood Derived Normal',
#  'Primary Tumor',
#  'Blood Derived Normal',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Blood Derived Normal',
#  'Blood Derived Normal',
#  'Blood Derived Normal',
#  'Solid Tissue Normal',
#  'Blood Derived Normal',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Solid Tissue Normal',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Blood Derived Normal',
#  'Primary Tumor',
#  'Blood Derived Normal',
# ...

# %%
metastage = meta['case.pathologic_stage'].tolist()
metastage
# Out:
# [nan,
#  nan,
#  'Stage II',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage II',
#  nan,
#  'Stage IVA',
#  'Stage I',
#  'Stage IVA',
#  'Stage II',
#  nan,
#  nan,
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVB',
#  'Stage IVA',
#  'Stage III',
#  'Stage IVA',
#  'Stage II',
#  'Stage IVA',
#  'Stage III',
#  'Stage IVA',
#  nan,
#  'Stage II',
#  'Stage I',
#  'Stage IVA',
#  'Stage II',
#  nan,
#  nan,
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage III',
#  'Stage III',
#  nan,
#  'Stage II',
#  nan,
#  'Stage I',
#  'Stage IVA',
#  'Stage II',
#  'Stage IVA',
#  'Stage I',
#  'Stage IVA',
#  nan,
#  'Stage II',
#  'Stage III',
#  nan,
#  nan,
#  'Stage IVA',
#  'Stage IVA',
#  'Stage I',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage III',
#  nan,
#  'Stage IVA',
#  'Stage IVA',
#  'Stage III',
#  'Stage III',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage III',
# ...

# %%
metasample
# Out:
# ['74dfb1a3-cdd5-4360-923f-2c18cd7e6044',
#  '17aee7fb-ed6f-46de-8dc7-ad13153b83a3',
#  'b54a3eac-9c58-453d-9db1-395601ae82ea',
#  'f81e667a-9c30-4093-8e59-c8fa7f8b772c',
#  'ab5f1c0e-d07d-49b4-9fc2-b74f3c4928a6',
#  'e5709830-4141-4354-94f0-94f576fe84c9',
#  '33b84364-a81e-48fd-89d6-552802c7ff18',
#  'e7b9cb7d-0a1a-4461-ab89-108d02821762',
#  'dac94d31-7c1f-4e4b-98af-a3a585b86fae',
#  '82ff50a2-3252-4ce5-a0ad-979cce2ec4cb',
#  '70f8bf18-8050-4dad-9029-c90972a9bfb4',
#  '3fb0505f-e847-4658-93f1-0af7d8617e66',
#  'c96f69ef-daa9-46cf-b34f-d7c328956edd',
#  'db7d0f46-b4eb-4cad-8324-08d0a5781624',
#  'bd85b141-d240-412f-9b74-379c4e3797d2',
#  '03c22e39-15a9-4b8a-8db1-cf41d618b7fc',
#  '2dc9d158-11f1-4d04-a6e6-8075121def2e',
#  '44d87ab1-c19b-4411-8774-2f888600c978',
#  '878f4d9b-a3fb-4517-9331-fe3b4590447e',
#  'bb531fb4-064f-47dd-8231-bd6131866968',
#  'e5e36209-eb45-4a7f-b70a-547a36daace6',
#  '3eb627a6-bbcf-4699-ad23-e52a26cd4453',
#  '7145e1a2-e609-45d9-a111-efe59656286d',
# ...

# %%
len(idf.columns), len(metastage), len(metatype)
# Out:
# (587, 1982, 1982)

# %%
metastage_list = []
metatype_list = []
idf_list = idf.columns.tolist()

# %%
for i in idf_list:
    for j in range (len(metasample)):
        if i == metasample[j]:
            metastage_list.append(metastage[j])
            metatype_list.append(metatype[j])

# %%
len(idf.columns), len(metastage_list), len(metatype_list)
# Out:
# (587, 587, 587)

# %%
metastage_list
# Out:
# ['Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage III',
#  nan,
#  'Stage IVA',
#  'Stage IVA',
#  'Stage III',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage I',
#  'Stage III',
#  'Stage III',
#  'Stage IVB',
#  'Stage III',
#  'Stage III',
#  nan,
#  nan,
#  'Stage III',
#  'Stage IVA',
#  nan,
#  'Stage IVA',
#  'Stage II',
#  'Stage IVA',
#  nan,
#  'Stage IVA',
#  'Stage II',
#  'Stage IVA',
#  'Stage II',
#  nan,
#  'Stage IVA',
#  'Stage I',
#  'Stage II',
#  nan,
#  'Stage IVA',
#  'Stage IVA',
#  'Stage III',
#  'Stage II',
#  nan,
#  'Stage IVA',
#  'Stage I',
#  'Stage I',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage III',
#  'Stage II',
#  'Stage II',
#  nan,
#  nan,
#  'Stage IVA',
#  nan,
#  'Stage IVB',
#  'Stage IVA',
#  'Stage IVA',
#  'Stage II',
#  'Stage II',
#  'Stage I',
#  'Stage IVA',
#  'Stage III',
# ...

# %%
metatype_list
# Out:
# ['Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Solid Tissue Normal',
#  'Solid Tissue Normal',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Solid Tissue Normal',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Solid Tissue Normal',
#  'Solid Tissue Normal',
#  'Primary Tumor',
#  'Solid Tissue Normal',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Solid Tissue Normal',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
#  'Primary Tumor',
# ...

# %%
metastage_list = pd.DataFrame(metastage_list)
metastage_list.to_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\hnsc\\stage.csv', index=False)

# %%
metatype_list = pd.DataFrame(metatype_list)
metatype_list.to_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\hnsc\\type.csv', index=False)

# %%
c1 = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\stad\\csvcleaned_file.csv')
c2 = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\esca\\csvcleaned_file.csv')
c3 = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\coad\\csvcleaned_file.csv')
c4 = pd.read_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\read\\csvcleaned_file.csv')

# %%
c1
# Out:
#      Unnamed: 0  001a4ac5-941f-464f-8f1a-e5f263fc00f0  \
# 0           2.0                                  65.1
# 1         194.0                                   0.0
# 2         203.0                                   0.0
# 3         204.0                                   0.0
# 4         815.0                                   0.0
# ..          ...                                   ...
# 101   1739543.0                                   0.0
# 102   1843489.0                                   0.0
# 103   1852365.0                                   0.0
# 104   1853231.0                                   0.0
# 105   1917878.0                                   0.0
#
#      003d6bd5-3ae8-4838-8cfc-0355ee16122d  \
# 0                                    3.75
# 1                                    0.00
# 2                                    0.00
# 3                                    0.00
# 4                                    0.00
# ..                                    ...
# ...

# %%
c2
# Out:
#      Unnamed: 0  0038dc24-f02e-4be2-8deb-19c081d7d548  \
# 0           2.0                                   0.0
# 1         194.0                                   0.0
# 2         203.0                                   0.0
# 3         204.0                                   0.0
# 4         815.0                                   0.0
# ..          ...                                   ...
# 101   1739543.0                                   0.0
# 102   1843489.0                                   0.0
# 103   1852365.0                                   0.0
# 104   1853231.0                                   0.0
# 105   1917878.0                                   0.0
#
#      00a7766f-f90c-45ea-afe2-2d505827c415  \
# 0                               37.695652
# 1                                0.000000
# 2                                0.000000
# 3                                0.000000
# 4                                0.000000
# ..                                    ...
# ...

# %%
concatenated_columns = pd.concat([c1, c2, c3, c4], axis=1)
concatenated_columns
# Out:
#      Unnamed: 0  001a4ac5-941f-464f-8f1a-e5f263fc00f0  \
# 0           2.0                                  65.1
# 1         194.0                                   0.0
# 2         203.0                                   0.0
# 3         204.0                                   0.0
# 4         815.0                                   0.0
# ..          ...                                   ...
# 101   1739543.0                                   0.0
# 102   1843489.0                                   0.0
# 103   1852365.0                                   0.0
# 104   1853231.0                                   0.0
# 105   1917878.0                                   0.0
#
#      003d6bd5-3ae8-4838-8cfc-0355ee16122d  \
# 0                                    3.75
# 1                                    0.00
# 2                                    0.00
# 3                                    0.00
# 4                                    0.00
# ..                                    ...
# ...

# %%
concatenated_columns.to_csv('D:\\TCGA\mbVDiT_data\\WXS\\solid\\hnsc\\pre_train.csv')

# %%
adata = ad.AnnData(concatenated_columns)
adata.write('D:\\TCGA\mbVDiT_data\\WXS\\solid\\hnsc\\pre_train.h5ad')
# Out:
# D:\Anaconda\envs\DL\lib\site-packages\anndata\_core\anndata.py:183: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# D:\Anaconda\envs\DL\lib\site-packages\anndata\_core\anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
import scanpy as sc
sstad = sc.read_h5ad("D:\\TCGA\mbVDiT_data\\WXS\\solid\\stad\\microdata.h5ad")
ccoad = sc.read_h5ad("D:\\TCGA\mbVDiT_data\\WXS\\solid\\coad\\microdata.h5ad")

# %%
sstad
# Out:
# AnnData object with n_obs × n_vars = 530 × 106

# %%
ccoad
# Out:
# AnnData object with n_obs × n_vars = 561 × 106

# %%
T = pd.read_csv("D:\\TCGA\mbVDiT_data\\WXS\\solid\\bacteria.WXS.solid.file.reads.csv")
T
# Out:
#       Unnamed: 0  00b7ee04-b97b-49ee-b27b-13f6fb981fec  \
# 0            2.0                          17350.620633
# 1           71.0                                   NaN
# 2           72.0                                   NaN
# 3          136.0                                   NaN
# 4          137.0                                   NaN
# ...          ...                                   ...
# 1284   1945592.0                                   NaN
# 1285   1965226.0                                   NaN
# 1286   1980675.0                                   NaN
# 1287   1980693.0                              0.000000
# 1288   1980697.0                              0.000000
#
#       00f789a0-bc97-48a3-abff-51d0acaff845  \
# 0                             202435.26647
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...

# %%
mic_data = pd.read_csv('D:\TCGA\mbVDiT_data\WXS\solid\\csvcleaned_file.csv', header=0, index_col=False, usecols=lambda column: column != 'Unnamed: 0').T
mic_data
# Out:
#                                                 0     1    2    3    \
# 00b7ee04-b97b-49ee-b27b-13f6fb981fec   17350.620633   0.0  0.0  0.0
# 00f789a0-bc97-48a3-abff-51d0acaff845  202435.266470  21.0  0.0  2.0
# 012fc920-2c94-4596-a937-9e6f6a3fffd8    1130.207006   0.0  0.0  0.0
# 014560ce-4236-4fbe-8f1c-ac5c67bc1517     112.375000   0.0  0.0  0.0
# 026ac354-163a-44c3-8b8e-25365c0998be     325.684211   3.0  0.0  0.0
# ...                                             ...   ...  ...  ...
# fe0ec0de-9a97-4154-81f7-0ec63f514bb7     212.198113   2.0  0.0  0.0
# fe61bfb4-b612-4675-83fb-086a0fed9f71      70.342205   0.0  0.0  0.0
# ff3d1fa3-5cc9-4614-aea9-e14e491ff021     179.643564   0.0  0.0  0.0
# ff6a1163-7552-4a4b-af31-eed78955489c       0.000000   0.0  0.0  0.0
# ff99c2ca-1bee-4b4f-a0ef-44dc7d6c1f31       0.000000   0.0  0.0  0.0
#
#                                                4             5      6    \
# 00b7ee04-b97b-49ee-b27b-13f6fb981fec  15343.000000  15343.000000    0.0
# ...

# %%
zero_counts = mic_data.eq(0).sum()
zero_ratio = zero_counts/2108
columns_with_high_zeros = zero_counts[zero_ratio >= 0.95].index
mic_data = mic_data.drop(columns=columns_with_high_zeros)
mic_data
# Out:
#                                                 0     1    2    3    \
# 00b7ee04-b97b-49ee-b27b-13f6fb981fec   17350.620633   0.0  0.0  0.0
# 00f789a0-bc97-48a3-abff-51d0acaff845  202435.266470  21.0  0.0  2.0
# 012fc920-2c94-4596-a937-9e6f6a3fffd8    1130.207006   0.0  0.0  0.0
# 014560ce-4236-4fbe-8f1c-ac5c67bc1517     112.375000   0.0  0.0  0.0
# 026ac354-163a-44c3-8b8e-25365c0998be     325.684211   3.0  0.0  0.0
# ...                                             ...   ...  ...  ...
# fe0ec0de-9a97-4154-81f7-0ec63f514bb7     212.198113   2.0  0.0  0.0
# fe61bfb4-b612-4675-83fb-086a0fed9f71      70.342205   0.0  0.0  0.0
# ff3d1fa3-5cc9-4614-aea9-e14e491ff021     179.643564   0.0  0.0  0.0
# ff6a1163-7552-4a4b-af31-eed78955489c       0.000000   0.0  0.0  0.0
# ff99c2ca-1bee-4b4f-a0ef-44dc7d6c1f31       0.000000   0.0  0.0  0.0
#
#                                                4             5      6    \
# 00b7ee04-b97b-49ee-b27b-13f6fb981fec  15343.000000  15343.000000    0.0
# ...
